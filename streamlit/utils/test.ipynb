# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/yiji/Desktop/ybigta/project/산학/EV_monit/streamlit/data/processed_station_data.csv")
df[df["statNm"].str.contains("휴게소")]
# Out:
#                     statNm    statId                        addr addrDetail  \
# 177         워터 평택호휴게소 평택방향  BE241201         경기도 평택시 현덕면 권관리 산95        NaN
# 178         워터 평택호휴게소 익산방향  BE241202                 경기도 평택시 현덕면        NaN
# 179     워터 평택호휴게소 외부입주민주차장  BE241203          경기 평택시 현덕면 권관리 산95        NaN
# 180       워터 예산예당호휴게소 평택방향  BE241204         충남 예산군 응봉면 신리 183-1        NaN
# 181       워터 예산예당호휴게소 익산방향  BE241205        충남 예산군 응봉면 신리길 78-10        NaN
# ...                    ...       ...                         ...        ...
# 29086  FILTSON 진영휴게소(부산방면)  SZBA0022   경상남도 김해시 진영읍 하계로96번길 94-4    부산방면주차장
# 29143                구포휴게소  TD000017  경상북도 포항시 남구 구룡포읍 동해안로 4131      구포휴게소
# 29624            상개 화물차휴게소  US200405             울산광역시 남구 상개동 50        NaN
# 29634            약수 화물차휴게소  US200415            울산광역시 북구 신천동 797        NaN
# 29647                계룡휴게소  VTE00062          대전광역시 유성구 현충원로 185      계룡휴게소
#
# ...
